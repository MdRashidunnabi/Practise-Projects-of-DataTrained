# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Import Dataset

# %%
sonar=pd.read_csv("Sonar.csv")
sonar.head()
# Out:
#        V1      V2      V3      V4      V5      V6      V7      V8      V9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       V10  ...     V52     V53     V54     V55     V56     V57     V58  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#       V59     V60  Class
# 0  0.0090  0.0032   Rock
# 1  0.0052  0.0044   Rock
# ...

# %%
 sonar.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
#        'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41',
#        'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50', 'V51',
#        'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60', 'Class'],
#       dtype='object')

# %%
sonar['Class'].nunique()
# Out:
# 2

# %%
sonar['Class'].unique()
# Out:
# array(['Rock', 'Mine'], dtype=object)

# %%
sonar.describe()
# Out:
#                V1          V2          V3          V4          V5          V6  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                V7          V8          V9         V10  ...         V51  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
sonar.isnull().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
#         ..
# V57      0
# V58      0
# V59      0
# V60      0
# Class    0
# Length: 61, dtype: int64

# %%
sns.heatmap(sonar.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation

# %%
sonar_corr=sonar.corr()
plt.subplots(figsize=(15,8))
sns.heatmap(sonar.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are no values present here

# %% [markdown]
# # Check Outliers

# %%
sonar.plot(kind='box',subplots=True,layout=(6,10),figsize=(12,16))
# Out:
# V1        AxesSubplot(0.125,0.772143;0.065678x0.107857)
# V2     AxesSubplot(0.203814,0.772143;0.065678x0.107857)
# V3     AxesSubplot(0.282627,0.772143;0.065678x0.107857)
# V4     AxesSubplot(0.361441,0.772143;0.065678x0.107857)
# V5     AxesSubplot(0.440254,0.772143;0.065678x0.107857)
# V6     AxesSubplot(0.519068,0.772143;0.065678x0.107857)
# V7     AxesSubplot(0.597881,0.772143;0.065678x0.107857)
# V8     AxesSubplot(0.676695,0.772143;0.065678x0.107857)
# V9     AxesSubplot(0.755508,0.772143;0.065678x0.107857)
# V10    AxesSubplot(0.834322,0.772143;0.065678x0.107857)
# V11       AxesSubplot(0.125,0.642714;0.065678x0.107857)
# V12    AxesSubplot(0.203814,0.642714;0.065678x0.107857)
# V13    AxesSubplot(0.282627,0.642714;0.065678x0.107857)
# V14    AxesSubplot(0.361441,0.642714;0.065678x0.107857)
# V15    AxesSubplot(0.440254,0.642714;0.065678x0.107857)
# V16    AxesSubplot(0.519068,0.642714;0.065678x0.107857)
# V17    AxesSubplot(0.597881,0.642714;0.065678x0.107857)
# ...

# %% [markdown]
# # Check and convert every values to numeric values

# %%
sonar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      208 non-null    float64
#  1   V2      208 non-null    float64
#  2   V3      208 non-null    float64
#  3   V4      208 non-null    float64
#  4   V5      208 non-null    float64
#  5   V6      208 non-null    float64
#  6   V7      208 non-null    float64
#  7   V8      208 non-null    float64
#  8   V9      208 non-null    float64
#  9   V10     208 non-null    float64
#  10  V11     208 non-null    float64
#  11  V12     208 non-null    float64
#  12  V13     208 non-null    float64
#  13  V14     208 non-null    float64
#  14  V15     208 non-null    float64
#  15  V16     208 non-null    float64
#  16  V17     208 non-null    float64
#  17  V18     208 non-null    float64
#  18  V19     208 non-null    float64
#  19  V20     208 non-null    float64
# ...

# %% [markdown]
# Class column is object column. Let me change it to numeric by marking Rock=1 and Mine=0

# %%
sonar['Class']=sonar.Class.apply(lambda x:0 if x=='Rock' else 1)

# %%
sonar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      208 non-null    float64
#  1   V2      208 non-null    float64
#  2   V3      208 non-null    float64
#  3   V4      208 non-null    float64
#  4   V5      208 non-null    float64
#  5   V6      208 non-null    float64
#  6   V7      208 non-null    float64
#  7   V8      208 non-null    float64
#  8   V9      208 non-null    float64
#  9   V10     208 non-null    float64
#  10  V11     208 non-null    float64
#  11  V12     208 non-null    float64
#  12  V13     208 non-null    float64
#  13  V14     208 non-null    float64
#  14  V15     208 non-null    float64
#  15  V16     208 non-null    float64
#  16  V17     208 non-null    float64
#  17  V18     208 non-null    float64
#  18  V19     208 non-null    float64
#  19  V20     208 non-null    float64
# ...

# %% [markdown]
# Now There are no objects column

# %% [markdown]
# There are a lot of outliers present here

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# # 1.Z score

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(sonar))
threshold=3
new_sonar=sonar[(z<3).all(axis=1)]

# %%
sonar.shape
# Out:
# (208, 61)

# %%
new_sonar.shape
# Out:
# (168, 61)

# %% [markdown]
# # 2. IQR

# %%
q1=sonar.quantile(0.25)
q3=sonar.quantile(0.75)
IQR=q3-q1
print(IQR)
# Out:
# V1       0.022200
# V2       0.031500
# V3       0.039000
# V4       0.040125
# V5       0.062225
#            ...
# V57      0.006725
# V58      0.006750
# V59      0.006650
# V60      0.005425
# Class    1.000000
# Length: 61, dtype: float64

# %%
new_sonar1=sonar[~((sonar<(q1-1.5*IQR))|(sonar>(q3+1.5*IQR))).any(axis=1)]

# %%
sonar.shape
# Out:
# (208, 61)

# %%
new_sonar1.shape
# Out:
# (134, 61)

# %% [markdown]
# # Check percentage of losing data

# %%
# Lose percentage for z score
percentage_loss=((40)/208)*100   
print(percentage_loss)
# Out:
# 19.230769230769234

# %%
# Lose percentage for IQR
percentage_loss=((74)/208)*100   
print(percentage_loss)
# Out:
# 35.57692307692308

# %% [markdown]
# We are loosing around 19% of data from the original dataset. So, let try to fix the model without removing outliers.

# %% [markdown]
# # Seperate target column and other columns

# %%
x=sonar.drop('Class',axis=1)
y=sonar['Class']

# %% [markdown]
# # USE PCA to reduce columns without removing data

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=10)

# %%
x=pca.fit_transform(x)

# %%
x.shape
# Out:
# (208, 10)

# %%
pd.DataFrame(data=x)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.576093  0.319393 -0.387291 -0.378009 -0.243780 -0.156243 -0.427736
# 1   -0.970667  1.018039  0.834156  0.107423  0.286070  0.178684 -0.260332
# 2   -0.325887  0.874209  0.246015  0.863031  0.069110 -0.300833 -0.412807
# 3    0.852035  0.690863 -0.013390 -0.110257 -0.554050  0.397968  0.492569
# 4   -0.064756  0.222968  0.638601  0.140432  0.135854  0.052881 -0.386558
# ..        ...       ...       ...       ...       ...       ...       ...
# 203  0.041781 -1.031644  0.265669  0.021516 -0.015439  0.097304  0.003784
# 204  0.219149 -1.153807  0.203619  0.045836  0.183272  0.012770  0.078507
# 205  0.297733 -1.151860  0.250096 -0.057702  0.163566  0.015275  0.045792
# 206 -0.045761 -0.995970  0.199677 -0.066516 -0.147227 -0.084600  0.031038
# 207 -0.051115 -0.912526  0.008910 -0.044387 -0.027915 -0.029949  0.033107
#
#             7         8         9
# 0    0.074832 -0.024347  0.318054
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 203    1
# 204    1
# 205    1
# 206    1
# 207    1
# Name: Class, Length: 208, dtype: int64

# %% [markdown]
# # Regression Model Building:

# %% [markdown]
# # Scaling

# %%
#Scaling the dataset using SrandardScaler
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaledx=sc.fit_transform(x)

# %%
#findinfg the best random state
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

best_rstate=0
accu=0
for i in range(30,200):
    x_train,x_test,y_train,y_test=train_test_split(scaledx,y,test_size=.25,random_state=i)
    mod=LogisticRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)   #What is the r2_score for particular random state
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
        
print(f"Best accuracy{accu*100} found on random_state{best_rstate}")
# Out:
# Best accuracy52.727272727272734 found on random_state152

# %%
# Creating train_test_split using best random_state
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(scaledx,y,test_size=.25,random_state=152)

# %% [markdown]
# # Logistic Regression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
predlr=lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 0.8846153846153846
# [[17  5]
#  [ 1 29]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85        22
#            1       0.85      0.97      0.91        30
#
#     accuracy                           0.88        52
#    macro avg       0.90      0.87      0.88        52
# weighted avg       0.89      0.88      0.88        52

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'random_state': 0}

# %%
ls=Lasso(alpha=.01,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
for j in range (2,10):
    lsscore=cross_val_score(ls,x_t,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross Validation Score is :- ", lsc*100)
    print("R2 score is :-", lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross Validation Score is :-  -692.8571428571429
# R2 score is :- 42.47525760271221
#
#
# At cv:- 3
# Cross Validation Score is :-  -11.029196641484347
# R2 score is :- 42.47525760271221
#
#
# At cv:- 4
# Cross Validation Score is :-  -42.330168876146736
# R2 score is :- 42.47525760271221
#
#
# At cv:- 5
# Cross Validation Score is :-  -13.261360938201255
# R2 score is :- 42.47525760271221
#
#
# At cv:- 6
# Cross Validation Score is :-  -14.01570246168474
# R2 score is :- 42.47525760271221
#
#
# At cv:- 7
# Cross Validation Score is :-  -22.372678110296977
# R2 score is :- 42.47525760271221
#
#
# At cv:- 8
# Cross Validation Score is :-  -9.560734788914147
# R2 score is :- 42.47525760271221
#
#
# At cv:- 9
# Cross Validation Score is :-  -30.67026244194467
# R2 score is :- 42.47525760271221

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print("Error")
print("Mean Absolute Eror : ",mean_absolute_error(y_test,pred_ls))
print("Mean Squared Eror : ",mean_squared_error(y_test,pred_ls))
print("Root Mean Squared Eror : ",np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Error
# Mean Absolute Eror :  0.3379961215283514
# Mean Squared Eror :  0.14040802508213737
# Root Mean Squared Eror :  0.37471058843077465

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

parameters={'criterion':['mse','friedman_mse','mae'],'splitter':['best','random']}
dt=DecisionTreeRegressor()
clf=GridSearchCV(dt,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'splitter': 'best'}

# %%
dt=DecisionTreeRegressor(criterion= 'mae', splitter= 'best')
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
pred_dt=dt.predict(x_test)

dts=r2_score(y_test,pred_dt)
print('R2 Score:',dts*100)

dtscore=cross_val_score(dt,x_t,y,cv=8)
dtc=dtscore.mean()
print('Cross Val Score : ',dtc*100)
# Out:
# R2 Score: -33.93939393939394
# Cross Val Score :  -16.823308270676694

# %% [markdown]
# # Logistic Regression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
pred_lr=lr.predict(x_test)

lrs=r2_score(y_test,pred_lr)
print('R2 Score:',lrs*100)

lrscore=cross_val_score(lr,x_t,y,cv=9)
lrc=lrscore.mean()
print('Cross Val Score : ',lrc*100)
# Out:
# R2 Score: 52.727272727272734
# Cross Val Score :  71.35668276972625

# %% [markdown]
# # Some Models together

# %%
import sklearn
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

model=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier()]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy score of',m,"is: ")
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is:
# 0.8846153846153846
# [[17  5]
#  [ 1 29]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.77      0.85        22
#            1       0.85      0.97      0.91        30
#
#     accuracy                           0.88        52
#    macro avg       0.90      0.87      0.88        52
# weighted avg       0.89      0.88      0.88        52
#
#
#
# Accuracy score of GaussianNB() is:
# 0.8461538461538461
# [[17  5]
#  [ 3 27]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81        22
#            1       0.84      0.90      0.87        30
#
#     accuracy                           0.85        52
#    macro avg       0.85      0.84      0.84        52
# weighted avg       0.85      0.85      0.84        52
#
#
#
# Accuracy score of SVC() is:
# 0.8653846153846154
# [[19  3]
#  [ 4 26]]
#               precision    recall  f1-score   support
#
# ...
